# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine

# %%
wine_load = load_wine()

# %%
wine = pd.DataFrame(wine_load.data, columns = wine_load.feature_names)

# %%
wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
wine['Class'] = wine_load.target

# %%
wine_type = wine['Class'].value_counts()

# %%
wine_type
# Out:
# Class
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
plt.bar(wine_type.index, wine_type.values, width = 0.8, bottom = None, align = 'center')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(wine_type.index, wine_type.values, width = 0.8, bottom = True, align = 'center')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(wine_type.index, wine_type.values, height = 0.8, left = None, align = 'edge')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.title('wine alcohol histogram')
plt.hist('alcohol', bins = 8, range= (11,15), color = 'purple', data = wine)
plt.show()

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris['class']= load_iris().target

# %%
plt.boxplot(iris.drop(columns = 'class'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c79c7eda90>,
#   <matplotlib.lines.Line2D at 0x2c79c7ec9d0>,
#   <matplotlib.lines.Line2D at 0x2c79c81a150>,
#   <matplotlib.lines.Line2D at 0x2c79c81b190>,
#   <matplotlib.lines.Line2D at 0x2c79d5db9d0>,
#   <matplotlib.lines.Line2D at 0x2c79d5e5790>,
#   <matplotlib.lines.Line2D at 0x2c79d5e7950>,
#   <matplotlib.lines.Line2D at 0x2c79d5f4090>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c79c7eead0>,
#   <matplotlib.lines.Line2D at 0x2c79c7ef8d0>,
#   <matplotlib.lines.Line2D at 0x2c79c81bb50>,
#   <matplotlib.lines.Line2D at 0x2c79c805f10>,
#   <matplotlib.lines.Line2D at 0x2c79d5e4a10>,
#   <matplotlib.lines.Line2D at 0x2c79d5e7e50>,
#   <matplotlib.lines.Line2D at 0x2c79d5f4a10>,
#   <matplotlib.lines.Line2D at 0x2c79d5f5290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c79c7f6cd0>,
#   <matplotlib.lines.Line2D at 0x2c79c819890>,
#   <matplotlib.lines.Line2D at 0x2c79d5db0d0>,
#   <matplotlib.lines.Line2D at 0x2c79d5e6f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c79c7ee5d0>,
#   <matplotlib.lines.Line2D at 0x2c79c806850>,
#   <matplotlib.lines.Line2D at 0x2c79d5e5910>,
#   <matplotlib.lines.Line2D at 0x2c79d5f5a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c79aa585d0>,
#   <matplotlib.lines.Line2D at 0x2c79c807b90>,
#   <matplotlib.lines.Line2D at 0x2c79d5e6650>,
#   <matplotlib.lines.Line2D at 0x2c79d5e46d0>],
#  'means': []}

# %%
plt.boxplot(iris['sepal width (cm)'], whis = 1.5)
plt.title('sepal width (cm)')
# Out:
# Text(0.5, 1.0, 'sepal width (cm)')

# %%
iris['class'] = iris['class'].map({0:'setosa', 1:'versicolour', 2:'virginica'})

# %%
iris[['sepal width (cm)','class']].boxplot(by = 'class')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='class',y='sepal width (cm)',data = iris)
plt.show()

# %% [markdown]
# # scatter plot
# ## 산점도 그리기

# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
iris = load_iris()
iris = pd.DataFrame(iris.data, columns = iris.feature_names)
iris['class'] = load_iris().target
iris['class'] = iris['class'].map({0:'setosa',1:'versicolour',2:'virginica'})

# %%
plt.title('iris scatter')
plt.xlabel('sepal length(cm)')
plt.ylabel('sepal width (cm)')
plt.scatter(x=iris['sepal length (cm)'], y = iris['sepal width (cm)'], alpha = 0.5)
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x = 'sepal length (cm)', y = 'sepal width (cm)', data = iris, hue = 'class', style = 'class')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# # 회귀선 그래프

# %%
import numpy as np

# %%
x,y = iris['sepal length (cm)'], iris['petal length (cm)']
b1,b0 = np.polyfit(x,y,1)
plt.scatter(x= x, y= y)
plt.plot(x, b1*x+b0,color= 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
b1
# Out:
# 1.8584329782548397

# %%
b0
# Out:
# -7.101443369602449

# %% [markdown]
# ###  2차 회귀식은 x값에 대하여 정렬이 필요하다 정렬하지 않으면 값이 오락가락 난리 부르스

# %%
iris2= iris.sort_values(by='sepal length (cm)')
x,y = iris['sepal length (cm)'], iris['petal length (cm)']
b2,b1,b0 = np.polyfit(x,y,2)
plt.scatter(x= x, y= y)
plt.plot(x, b1*x+b0+b2*x**2,color= 'red', alpha = 0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 상관관계 시각화

# %% [markdown]
# # 산점도 행렬

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pandas.plotting import scatter_matrix
from sklearn.datasets import load_iris
iris = load_iris()
iris = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
iris['class'] = load_iris().target
iris['class'] = iris['class'].map({0:'setosa',1:'versicolour', 2:'virginica'})
scatter_matrix(iris, alpha = 0.5, figsize = (8,8), diagonal = 'hist')
plt.show()

# %%
import seaborn as sns
sns.pairplot(iris, diag_kind = 'auto', hue = 'class')
plt.show()
# Out:
# C:\Users\tjtnd\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 상관계수 행렬 그래프 methos = perason, kendall, spearman

# %%
iris_corr = iris.drop(columns = 'class').corr(method = 'pearson')
sns.heatmap(iris_corr, xticklabels = iris_corr.columns, yticklabels = iris_corr.columns, cmap = 'RdBu_r', annot = True)
plt.show()

# %%
#코랩환경일 경우 밑 코드부터 실행
# !pip uninstall pandas_profiling
# Out:
# ^C

# %%
# !pip install pandas-profiling[notebook,html]
# Out:
# Requirement already satisfied: pandas-profiling[html,notebook] in c:\users\tjtnd\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (1.11.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (2.0.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (3.7.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (1.24.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (1.10)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (7.4.9)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (5.3.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (8.0.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[html,notebook]) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[html,notebook]) (3.1)
# Requirement already satisfied: imagehash in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[html,notebook]) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[html,notebook]) (9.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (3.0.5)
# Requirement already satisfied: entrypoints in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (23.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (6.3.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[html,notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\tjtnd\anaconda3\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[html,notebook]) (305.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[html,notebook]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[html,notebook]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[html,notebook]) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[html,notebook]) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling[html,notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling[html,notebook]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling[html,notebook]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling[html,notebook]) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\tjtnd\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling[html,notebook]) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.1.6)
# Requirement already satisfied: psutil in c:\users\tjtnd\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (5.9.0)
# Requirement already satisfied: backcall in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\tjtnd\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->pandas-profiling[html,notebook]) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\tjtnd\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling[html,notebook]) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\tjtnd\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.2.5)
# Requirement already satisfied: executing in c:\users\tjtnd\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\tjtnd\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\tjtnd\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[html,notebook]) (0.2.2)
# WARNING: pandas-profiling 3.2.0 does not provide the extra 'html'

# %%
pip install --upgrade pandas pandas_profiling
# Out:
# Requirement already satisfied: pandas in c:\users\tjtnd\anaconda3\lib\site-packages (2.0.3)
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/2d/5e/9213ea10ac473e2437dc2cb17323ddc0999997e2713d6a0b683b10773994/pandas-2.1.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pandas-2.1.1-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: pandas_profiling in c:\users\tjtnd\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (1.11.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (3.7.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from pandas_profiling) (1.10)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (3.1)
# Requirement already satisfied: imagehash in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\tjtnd\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\tjtnd\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (4.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tjtnd\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\tjtnd\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas_profiling) (0.4.6)
# Requirement already satisfied: PyWavelets in c:\users\tjtnd\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.4.1)
# Downloading pandas-2.1.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 1.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/10.6 MB 6.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/10.6 MB 8.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.6 MB 9.9 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.6 MB 12.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.6 MB 15.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.6 MB 17.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/10.6 MB 18.4 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.6 MB 20.3 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 20.9 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.6 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 19.2 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# Successfully installed pandas-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[91], line 3
#       1 import pandas as pd
#       2 from sklearn.datasets import load_iris
# ----> 3 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\profile_report.py:15
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
# ---> 15 from pandas_profiling.model.alerts import AlertType
#      16 from pandas_profiling.model.describe import describe as describe_df
#      17 from pandas_profiling.model.sample import Sample
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\model\alerts.py:10
#       7 import pandas as pd
#       9 from pandas_profiling.config import Settings
# ---> 10 from pandas_profiling.model.correlations import perform_check_correlation
#      13 @unique
#      14 class AlertType(Enum):
#      15     """Alert types"""
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\model\correlations.py:8
#       6 import pandas as pd
#       7 from multimethod import multimethod
# ----> 8 from pandas.core.base import DataError
#      10 from pandas_profiling.config import Settings
#      13 class Correlation:
#
# ImportError: cannot import name 'DataError' from 'pandas.core.base' (C:\Users\tjtnd\anaconda3\Lib\site-packages\pandas\core\base.py)

# %%
iris = load_iris()

# %%
iris = pd.DataFrame(iris.data, columns=iris.feature_names)
iris['Class'] = load_iris().target
iris['Class'] = iris['Class'].map({0:'setosa',1:'versicolour',2:'virginica'})
ProfileReport(iris)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 4
#       2 iris['Class'] = load_iris().target
#       3 iris['Class'] = iris['Class'].map({0:'setosa',1:'versicolour',2:'virginica'})
# ----> 4 ProfileReport(iris)
#
# NameError: name 'ProfileReport' is not defined
